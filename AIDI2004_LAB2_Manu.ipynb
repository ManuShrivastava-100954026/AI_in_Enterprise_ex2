# %%
pip install ucimlrepo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
breast_cancer_data = fetch_ucirepo(id=17) 
#Print the dataset in original form.
breast_cancer_data.data.original
# Out:
#            ID  radius1  texture1  perimeter1   area1  smoothness1  \
# 0      842302    17.99     10.38      122.80  1001.0      0.11840
# 1      842517    20.57     17.77      132.90  1326.0      0.08474
# 2    84300903    19.69     21.25      130.00  1203.0      0.10960
# 3    84348301    11.42     20.38       77.58   386.1      0.14250
# 4    84358402    20.29     14.34      135.10  1297.0      0.10030
# ..        ...      ...       ...         ...     ...          ...
# 564    926424    21.56     22.39      142.00  1479.0      0.11100
# 565    926682    20.13     28.25      131.20  1261.0      0.09780
# 566    926954    16.60     28.08      108.30   858.1      0.08455
# 567    927241    20.60     29.33      140.10  1265.0      0.11780
# 568     92751     7.76     24.54       47.92   181.0      0.05263
#
#      compactness1  concavity1  concave_points1  symmetry1  ...  texture3  \
# 0         0.27760     0.30010          0.14710     0.2419  ...     17.33
# ...

# %%
# Diving data (as pandas dataframes) based on the data recieved from the repo.
X = breast_cancer_data.data.features 
y = breast_cancer_data.data.targets 
  
X.head()
# Out:
#    radius1  texture1  perimeter1   area1  smoothness1  compactness1  \
# 0    17.99     10.38      122.80  1001.0      0.11840       0.27760
# 1    20.57     17.77      132.90  1326.0      0.08474       0.07864
# 2    19.69     21.25      130.00  1203.0      0.10960       0.15990
# 3    11.42     20.38       77.58   386.1      0.14250       0.28390
# 4    20.29     14.34      135.10  1297.0      0.10030       0.13280
#
#    concavity1  concave_points1  symmetry1  fractal_dimension1  ...  radius3  \
# 0      0.3001          0.14710     0.2419             0.07871  ...    25.38
# 1      0.0869          0.07017     0.1812             0.05667  ...    24.99
# 2      0.1974          0.12790     0.2069             0.05999  ...    23.57
# 3      0.2414          0.10520     0.2597             0.09744  ...    14.91
# 4      0.1980          0.10430     0.1809             0.05883  ...    22.54
#
#    texture3  perimeter3   area3  smoothness3  compactness3  concavity3  \
# ...

# %%
print(y.head())
y.shape
# Out:
#   Diagnosis
# 0         M
# 1         M
# 2         M
# 3         M
# 4         M
# (569, 1)

# %%
#checking for the NULL values. 
X.isnull().sum()
y.isnull().sum()
# Out:
# Diagnosis    0
# dtype: int64

# %%
# Handle missing values if any (assuming mean imputation for simplicity)
X.fillna(X.mean(), inplace=True)
# Out:
# C:\Users\mymai\AppData\Local\Temp\ipykernel_700\302680920.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.fillna(X.mean(), inplace=True)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.decomposition import PCA
import pandas as pd

y = pd.Series(y)  # Ensure y is a pandas Series (one-dimenional ndarray) for easier handling


# Encode target variable if necessary using the label encoder.
if y.dtype == 'object':
    le = LabelEncoder()
    y = le.fit_transform(y)

# Feature scaling for regularization of data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Apply PCA for dimensionality reduction
pca = PCA(n_components=0.95)  # retain 95% of variance
X_pca = pca.fit_transform(X_scaled)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_pca, y, test_size=0.2, random_state=42)

# %%
# Display shapes of the resulting datasets
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (455, 10)
# X_test shape: (114, 10)
# y_train shape: (455,)
# y_test shape: (114,)

# %%
pca = PCA(n_components=0.95)  # retain 95% of variance
X_pca = pca.fit_transform(X_scaled)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# Initialize the model
model = LogisticRegression(random_state=42)

# Train the model
model.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=42)

# %%
# Predict on the test data
y_pred = model.predict(X_test)

# Evaluate the model
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
print("Accuracy Score:", accuracy_score(y_test, y_pred))
# Out:
# Confusion Matrix:
#  [[70  1]
#  [ 1 42]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99        71
#            1       0.98      0.98      0.98        43
#
#     accuracy                           0.98       114
#    macro avg       0.98      0.98      0.98       114
# weighted avg       0.98      0.98      0.98       114
#
# Accuracy Score: 0.9824561403508771

# %%
from sklearn.model_selection import GridSearchCV

# Define the parameter grid
param_grid = {
    'C': [0.1, 1, 10, 100],
    'solver': ['liblinear', 'saga']
}

# Initialize GridSearchCV
grid_search = GridSearchCV(LogisticRegression(random_state=42), param_grid, cv=5, scoring='accuracy')

# Fit the model
grid_search.fit(X_train, y_train)

# Best parameters and score
print("Best Parameters:", grid_search.best_params_)
print("Best Cross-Validation Score:", grid_search.best_score_)

# Use the best estimator for prediction
best_model = grid_search.best_estimator_
y_pred_best = best_model.predict(X_test)

# Evaluate the best model
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_best))
print("Classification Report:\n", classification_report(y_test, y_pred_best))
print("Accuracy Score:", accuracy_score(y_test, y_pred_best))
# Out:
# Best Parameters: {'C': 0.1, 'solver': 'liblinear'}
# Best Cross-Validation Score: 0.9780219780219781
# Confusion Matrix:
#  [[71  0]
#  [ 1 42]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99        71
#            1       1.00      0.98      0.99        43
#
#     accuracy                           0.99       114
#    macro avg       0.99      0.99      0.99       114
# weighted avg       0.99      0.99      0.99       114
#
# Accuracy Score: 0.9912280701754386
# C:\Users\mymai\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\mymai\anaconda3\Lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# ...

# %%
from sklearn.model_selection import cross_val_score

# Perform cross-validation
cv_scores = cross_val_score(best_model, X_train, y_train, cv=5)

# Cross-validation results
print("Cross-Validation Scores:", cv_scores)
print("Mean CV Score:", cv_scores.mean())
print("Standard Deviation CV Score:", cv_scores.std())
# Out:
# Cross-Validation Scores: [0.98901099 0.96703297 0.98901099 0.97802198 0.96703297]
# Mean CV Score: 0.9780219780219781
# Standard Deviation CV Score: 0.009828870230768321

# %%
import joblib

# Save the model
joblib.dump(best_model, 'logistic_regression_model.pkl')

# Load the model
loaded_model = joblib.load('logistic_regression_model.pkl')
